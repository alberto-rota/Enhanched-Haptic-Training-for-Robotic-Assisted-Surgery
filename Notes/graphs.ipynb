# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
mpl.rc('text', usetex=True)
import numpy as np

# %%
plt.xticks()
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
dfun = pd.read_csv("C:\\Users\\alber\\Desktop\\Suturing_0\\Suturing_0_VFs.csv",index_col=None)
dfas = pd.read_csv("C:\\Users\\alber\\Desktop\\Suturing_1\\Suturing_1_VFs.csv",index_col=None)

plt.figure(figsize=(10,3))
plt.plot(dfas['Time']-dfas['Time'][0],dfas['TrajectoryOrientationGuidanceVFRL_dist0']*1000,label='Assisted')
plt.plot(dfun['Time']-dfun['Time'][0],dfun['TrajectoryOrientationGuidanceVFRL_dist0']*1000,label='Unassisted')
plt.legend()
plt.grid()

plt.xlabel("Time [s] since beginning of the task")
plt.ylabel("Error [mm]")
plt.title("\\bf{Distance from preop-planned trajectory}")
plt.show()

# %%
dfun = pd.read_csv("C:\\Users\\alber\\Desktop\\Suturing_0\\Suturing_0_VFs.csv",index_col=None)
dfas = pd.read_csv("C:\\Users\\alber\\Desktop\\Suturing_1\\Suturing_1_VFs.csv",index_col=None)

plt.figure(figsize=(10,3))
plt.plot(dfas['Time']-dfas['Time'][0],dfas['TrajectoryOrientationGuidanceVFRL_angle0'],label='Assisted')
plt.plot(dfun['Time']-dfun['Time'][0],dfun['TrajectoryOrientationGuidanceVFRL_angle0'],label='Unassisted')
plt.legend()
plt.grid()

plt.xlabel("Time [s] since beginning of the task")
plt.ylabel("Error [degrees]")
plt.title("\\bf{Angular error to preop-planned trajectory}")
plt.show()

# %% [markdown]
# # Grafici per Anna

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
data = pd.read_csv("C:\\Users\\alber\\Desktop\\Active_Constraints\\Assessment\\Results\\Suturing.csv")
data
# Out:
#     idx subject      task  repetition  assisted  assistance      time  \
# 0     0       A  Suturing           0     False         1.0  20.61033
# 1     1       A  Suturing           1     False         1.0  23.98033
# 2     2       A  Suturing          10      True         1.0  20.80640
# 3     3       A  Suturing          11      True         1.0  18.98920
# 4     4       A  Suturing          12      True         1.0  17.78300
# ..  ...     ...       ...         ...       ...         ...       ...
# 59   60       N  Suturing           5     False         1.0  21.64980
# 60   61       N  Suturing           6     False         1.0  28.50110
# 61   62       N  Suturing           7     False         1.0  20.19710
# 62   63       N  Suturing           8      True         1.0  78.12720
# 63   64       N  Suturing           9      True         1.0  53.19300
#
#     missexchanges  clutch_time  avg_dist  avg_angle  avg_force  avg_torque
# ...

# %%
anna = data.loc[data['subject']=='N']
ass = anna.loc[data['assisted']==True]
nass = anna.loc[data['assisted']==False]
print(ass)
print(nass)

plt.boxplot([ass['avg_dist'],nass['avg_dist']],labels=['Assisted','Unassisted'])
plt.show()
plt.boxplot([ass['avg_angle'],nass['avg_angle']],labels=['Assisted','Unassisted'])
plt.show()
plt.boxplot([ass['avg_force'],nass['avg_force']],labels=['Assisted','Unassisted'])
plt.show()

plt.boxplot([ass['avg_torque'],nass['avg_torque']],labels=['Assisted','Unassisted'])
plt.show()
# Out:
#     idx subject      task  repetition  assisted  assistance     time  \
# 50   51       N  Suturing          10      True         1.0  55.8474
# 51   52       N  Suturing          11      True         1.0  51.7600
# 52   53       N  Suturing          12      True         1.0  28.6514
# 53   54       N  Suturing          13      True         1.0  22.5199
# 54   55       N  Suturing          14      True         1.0  22.7931
# 55   56       N  Suturing          15      True         1.0  22.4486
# 62   63       N  Suturing           8      True         1.0  78.1272
# 63   64       N  Suturing           9      True         1.0  53.1930
#
#     missexchanges  clutch_time  avg_dist  avg_angle  avg_force  avg_torque
# 50            0.0          0.0  0.004337  27.523998   0.331356    0.008609
# 51            0.0          0.0  0.004454  25.680738   0.311459    0.008267
# 52            1.0          0.0  0.003259  30.431214   0.237815    0.008410
# ...

# %%
anna = data.loc[data['subject']=='G']
ass = anna.loc[data['assisted']==True]
nass = anna.loc[data['assisted']==False]
print(ass)
print(nass)

plt.boxplot([ass['avg_dist'],nass['avg_dist']],labels=['Assisted','Unassisted'])
plt.show()
# Out:
#     idx subject      task  repetition  assisted  assistance     time  \
# 34   34       L  Suturing          10      True         1.0   43.056
# 35   35       L  Suturing          11      True         1.0   36.699
# 36   36       L  Suturing          12      True         1.0   54.259
# 37   37       L  Suturing          13      True         1.0   66.215
# 38   38       L  Suturing          14      True         1.0   57.205
# 39   39       L  Suturing          15      True         1.0  236.725
# 44   44       L  Suturing           6      True         1.0   27.507
# 45   45       L  Suturing           7      True         1.0   32.706
# 46   46       L  Suturing           8      True         1.0   54.171
# 47   47       L  Suturing           9      True         1.0   64.679
#
#     missexchanges  clutch_time  avg_dist  avg_angle  avg_force  avg_torque
# 34            0.0     0.000000  0.003926  19.022566   0.219221    0.007891
# ...

# %%
plt.boxplot([ass['avg_angle'],nass['avg_angle']],labels=['Assisted','Unassisted'])
plt.show()

# %%
plt.boxplot([ass['avg_force'],nass['avg_force']],labels=['Assisted','Unassisted'])
plt.show()

# %%
plt.boxplot([ass['avg_torque'],nass['avg_torque']],labels=['Assisted','Unassisted'])
plt.show()

# %%
anna = data.loc[data['subject']=='G']
ass = anna.loc[data['assisted']==True]
nass = anna.loc[data['assisted']==False]
print(ass)
print(nass)

plt.boxplot([ass['avg_dist'],nass['avg_dist']],labels=['Assisted','Unassisted'])
plt.show()
# Out:
#     idx subject      task  repetition  assisted  assistance     time  \
# 18   18       G  Suturing          10      True         1.0  21.7140
# 19   19       G  Suturing          11      True         1.0  19.3698
# 20   20       G  Suturing          12      True         1.0  30.7344
# 21   21       G  Suturing          13      True         1.0  33.0518
# 22   22       G  Suturing          14      True         1.0  34.9492
# 23   23       G  Suturing          15      True         1.0  55.0930
# 30   30       G  Suturing           8      True         1.0  38.8171
# 31   31       G  Suturing           9      True         1.0  20.6715
#
#     missexchanges  clutch_time  avg_dist  avg_angle  avg_force  avg_torque
# 18            1.0     0.000000  0.004745  22.161337   0.250431    0.007909
# 19            1.0     0.000000  0.005526  28.370679   0.264804    0.008303
# 20            0.0     0.000000  0.006776  28.704051   0.234869    0.005580
# ...

# %%
plt.boxplot([ass['avg_angle'],nass['avg_angle']],labels=['Assisted','Unassisted'])
plt.show()

# %%
plt.boxplot([ass['avg_force'],nass['avg_force']],labels=['Assisted','Unassisted'])
plt.show()
