# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams.update(plt.rcParamsDefault)
import numpy as np

# %%
dfun = pd.read_csv("C:\\Users\\alber\\Desktop\\Active_Constraints\\Assessment\\Pre-Study\\SubjectX\\Suturing\\Suturing_0\\Suturing_0_VFs.csv",index_col=None)
dfas = pd.read_csv("C:\\Users\\alber\\Desktop\\Active_Constraints\\Assessment\\Pre-Study\\SubjectX\\Suturing\\Suturing_1\\Suturing_1_VFs.csv",index_col=None)

plt.figure()
plt.plot(dfas['TrajectoryOrientationGuidanceVFRL_dist0'],label='Assisted')
plt.plot(dfun['TrajectoryOrientationGuidanceVFRL_dist0'],label='Unassisted')
plt.legend()
plt.figure()
plt.plot(dfas['TrajectoryOrientationGuidanceVFRL_angle0'],label="Assisted")
plt.plot(dfun['TrajectoryOrientationGuidanceVFRL_angle0'],label="Unassisted")
plt.legend()

# %%
plt.plot(dfas['TrajectoryOrientationGuidanceVFRL_angle0'],label="Assisted")
plt.plot(dfun['TrajectoryOrientationGuidanceVFRL_angle0'],label="Unassisted")
plt.legend()
